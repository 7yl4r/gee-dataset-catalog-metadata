# %%
DOCS_YML_LN = "https://github.com/samapriya/awesome-gee-community-datasets/raw/master/mkdocs.yml"
PROJECT_MD_DIR = "https://github.com/samapriya/awesome-gee-community-datasets/raw/master/docs"

import urllib.request
# display(response.read())
# dir(response)
import yaml


EXCLUDED_NAV_ITEMS = ['index.md', 'stats.md', 'license.md', 'changelog.md']
with urllib.request.urlopen(DOCS_YML_LN) as stream:
    yaml_dict = yaml.load(stream, Loader=yaml.BaseLoader)

# %%
import pandas
datasets = pandas.DataFrame(
    columns=['category_name', 'title', 'md_file']
)
for nav_item in yaml_dict['nav']:
    for category_name in nav_item:  # there is only one key
        if nav_item[category_name] not in EXCLUDED_NAV_ITEMS:
            for dataset in nav_item[category_name]:
                for dataset_name in dataset:  # only one key
                    dataset_dict = {
                        'category_name': category_name,
                        'title': dataset_name,
                        'md_file': dataset[dataset_name],
                    }
                    # dataset_list = [category_name, dataset_name, dataset[dataset_name]]
                    # print(dataset_dict)
                    datasets = datasets.append(dataset_dict, ignore_index=True)
                    
# display(datasets)

# %%
import urllib.request
import re

YR_REGEX_19 = "[^0-9]19[3-9][0-9][^0-9]"  # 1930-1999
YR_REGEX_2k = "[^0-9]20[0-9]{2}[^0-9]"  # 2000-2099
YR_REGEX = f"{YR_REGEX_19}|{YR_REGEX_2k}"

def scrape_years(text):
    """
    Returns a list of all years mentioned in the given text string.
    Assumes that data is between years 1930-2099.
    """
    yr_list = [int(yr[1:-1]) for yr in re.compile(YR_REGEX).findall(text)]
    return yr_list


def guess_data_freq_from_yrs_mentioned(years_mentioned):
    """
    Estimates temporal frequency of data from a list of years that were mentioned
    in a text. The years should be in the order that they appeared in the text.
    
    TODO: deal with year ranges (eg 2000-2010)
    """
    yr_df = pandas.DataFrame(years_mentioned, columns=['year'])
    yr_df['dt'] = yr_df.diff()
    # yr_df['ddt'] = yr_df['dt'].diff()
    yr_df['cumul_dts'] = yr_df.groupby('dt').cumcount()
    yr_df['cumul_dts_dt'] = yr_df['cumul_dts'].diff()
    yr_df['cumul_cumul_dts_dt'] = yr_df.groupby('cumul_dts_dt').cumcount()
    estimated_data_frequency = yr_df.iloc[yr_df['cumul_cumul_dts_dt'].idxmax()]['dt']
    return estimated_data_frequency


def guess_datatype(text):
    """
    Guesses GEE dataset datatype based on readme text
    """
    text = text.lower()
    # regex searches that hint at what type of data this is:
    FEATURE_COLLECTION_HINTS = [  # TODO: these could be weighted by how good of a hint they are
        'featurecollection',
        'point',
        'vector',
        'ee.featurecollection',
    ]
    IMAGE_COLLECTION_HINTS = [
        'arc[ -]?second',
        'image',
        'imagecollection',
        'raster',
        'ee.image',

    ]
    n_fc_hints = sum([len(re.compile(hint).findall(text)) for hint in FEATURE_COLLECTION_HINTS])
    n_ic_hints = sum([len(re.compile(hint).findall(text)) for hint in IMAGE_COLLECTION_HINTS])
    if n_fc_hints >= n_ic_hints:  # if more feature collection hints
        return 'FeatureCollection'
    else:
        return 'ImageCollection||Image'

def guess_updated_year(text):
    """
    Estimates when the dataset was updated by looking for the word "update" followed by a date.
    When multiple "update" years found, returns the most common one.
    """
    update_years = []
    for text_after_update_chunk in text.split("update")[1:]:
        # get first year following the word "update"
        update_years.append(int(
            re.compile(YR_REGEX).findall(text_after_update_chunk)[0][1:-1]
        ))
    return max(set(update_years), key=update_years.count)  # return mode


def guess_spatial_resolution(text):
    """
    Guesses spatial frequency from text about the dataset.
    When multiple possible frequencies found, returns the most common one.
    
    Returns
    -------
    int
        length of one pixel edge in meters
    """
    SPATIAL_UNIT_SUFFIXES = [
        # unit, multiplier
        ['km', 1000],
        ['m', 1],
        # TODO: arcseconds
    ]
    text = text.lower()

    resolutions = []
    for unit in SPATIAL_UNIT_SUFFIXES:
        regex = re.compile("([0-9]+)[ ]?" + unit[0] + " ")
        resolutions += [float(res)*unit[1] for res in regex.findall(text)]
    return resolutions

def guess_data_level(text):
    """
    Returns NASA data processing level (L0-L4) guessed from given text.
    [lvl ref](https://earthdata.nasa.gov/collaborate/open-data-services-and-software/data-information-policy/data-levels)
    """
    return "TODO"

def parse_dataset_md(md_url):
    """
    fetches .md file from the given url, reads the file, and returns whatever dataset metadata was able to be gleaned from the text.
    """
    with urllib.request.urlopen(md_url) as response:
        text = response.read().decode('utf-8')
        years_mentioned = scrape_years(text)
        # TODO: could parse these further to glean info from order & adjacent year diffs
        metadata = {}
        for metadata_guess in [
            # [ var name, var getter function, kwargs, default value]
            ["years_mentioned", None, None, years_mentioned],
            ["temporal_resolution_yrs", guess_data_freq_from_yrs_mentioned, years_mentioned, 'NaT'],
            ["spatial_resolution_m", guess_spatial_resolution, text, 'NaN'],
            ["datatype", guess_datatype, text, '?'],
            ["updated_year", guess_updated_year, text, 'NaT'],
            ["processing_level", guess_data_level, text, 'L?'],
        ]:
            key, guesser_fn, guesser_arg, default_val = metadata_guess
            try:
                metadata[key] = guesser_fn(guesser_arg)
            except:
                metadata[key] = default_val
        return metadata
    
# def test_apply(row):
#     return parse_dataset_md(f"{PROJECT_MD_DIR}/{row['md_file']}")
    
    
# for each row in datasets:
# append rows from
# parse_dataset_md(f"{PROJECT_MD_DIR}/projects/aogcm_cmip6.md")
# for index, row in datasets.iterrows():
#     # display(row)
#     metadata = parse_dataset_md(f"{PROJECT_MD_DIR}/{row['md_file']}")
#     # row.append(metadata)
#     display(metadata)
def wrapper_fn(row):
    print('.', end='')
    # print(f"guessing stuff about {row['title']}")
    return parse_dataset_md(f"{PROJECT_MD_DIR}/{row['md_file']}")

# use use the guess metatadata fn on every row
datasets["guessed_metadata"] = datasets.apply(wrapper_fn, axis=1)
# explode the metadata dict into columns
datasets = datasets.join(pandas.json_normalize(datasets['guessed_metadata']))
del datasets['guessed_metadata']


# display(
#     datasets.append(
#         parse_dataset_md(f"{PROJECT_MD_DIR}/{datasets.loc[0]['md_file']}"),
#         ignore_index = True,
#     )
# )
# Out:
# .......................................................................................

# %%
pandas.set_option('display.max_rows', datasets.shape[0]+1)
display(datasets)
# Out:
#                                         category_name  \
# 0                          Population & Socioeconomic
# 1                          Population & Socioeconomic
# 2                          Population & Socioeconomic
# 3                          Population & Socioeconomic
# 4                          Population & Socioeconomic
# 5                          Population & Socioeconomic
# 6                          Population & Socioeconomic
# 7            Geophysical, Biological & Biogeochemical
# 8            Geophysical, Biological & Biogeochemical
# 9            Geophysical, Biological & Biogeochemical
# 10           Geophysical, Biological & Biogeochemical
# 11           Geophysical, Biological & Biogeochemical
# 12           Geophysical, Biological & Biogeochemical
# 13           Geophysical, Biological & Biogeochemical
# 14           Geophysical, Biological & Biogeochemical
# 15                                    Soil Properties
# 16                                    Soil Properties
# 17                                    Soil Properties
# 18                                    Soil Properties
# 19                                    Soil Properties
# 20                     Global Land Use and Land Cover
# 21                     Global Land Use and Land Cover
# 22                     Global Land Use and Land Cover
# 23                     Global Land Use and Land Cover
# 24                     Global Land Use and Land Cover
# 25                     Global Land Use and Land Cover
# 26                   Regional Land Use and Land Cover
# 27                   Regional Land Use and Land Cover
# 28                   Regional Land Use and Land Cover
# 29                   Regional Land Use and Land Cover
# 30                   Regional Land Use and Land Cover
# 31                   Regional Land Use and Land Cover
# 32                   Regional Land Use and Land Cover
# 33                   Regional Land Use and Land Cover
# 34                   Regional Land Use and Land Cover
# 35                                          Hydrology
# 36                                          Hydrology
# 37                                          Hydrology
# 38                                          Hydrology
# 39                                          Hydrology
# 40                                          Hydrology
# 41                                          Hydrology
# 42                                          Hydrology
# 43                                          Hydrology
# 44                                          Hydrology
# 45                                          Hydrology
# 46                                          Hydrology
# 47               Agriculture, Vegetation and Forestry
# 48               Agriculture, Vegetation and Forestry
# 49               Agriculture, Vegetation and Forestry
# 50               Agriculture, Vegetation and Forestry
# 51               Agriculture, Vegetation and Forestry
# 52               Agriculture, Vegetation and Forestry
# 53               Agriculture, Vegetation and Forestry
# 54               Agriculture, Vegetation and Forestry
# 55      Global Utilities, Assets and Amenities Layers
# 56      Global Utilities, Assets and Amenities Layers
# 57      Global Utilities, Assets and Amenities Layers
# 58      Global Utilities, Assets and Amenities Layers
# 59      Global Utilities, Assets and Amenities Layers
# 60      Global Utilities, Assets and Amenities Layers
# 61      Global Utilities, Assets and Amenities Layers
# 62      Global Utilities, Assets and Amenities Layers
# 63      Global Utilities, Assets and Amenities Layers
# 64      Global Utilities, Assets and Amenities Layers
# 65      Global Utilities, Assets and Amenities Layers
# 66      Global Utilities, Assets and Amenities Layers
# 67      Global Utilities, Assets and Amenities Layers
# 68  EarthEnv Biodiversity ecosystems & climate Layers
# 69  EarthEnv Biodiversity ecosystems & climate Layers
# 70  EarthEnv Biodiversity ecosystems & climate Layers
# 71  EarthEnv Biodiversity ecosystems & climate Layers
# 72                         Weather and Climate Layers
# 73                         Weather and Climate Layers
# 74                         Weather and Climate Layers
# 75                         Weather and Climate Layers
# 76                         Weather and Climate Layers
# 77                         Weather and Climate Layers
# 78                         Weather and Climate Layers
# 79                         Weather and Climate Layers
# 80                         Weather and Climate Layers
# 81                               Global Events Layers
# 82                               Global Events Layers
# 83                               Global Events Layers
# 84                               Global Events Layers
# 85                               Global Events Layers
# 86                               Global Events Layers
#
#                                                 title  \
# 0                   High Resolution Settlement Layers
# 1                           GPW Version 4 Admin Units
# 2   geoBoundaries Global Database of Political Adm...
# 3           West Africa Coastal Vulnerability Mapping
# 4                         Relative Wealth Index (RWI)
# 5                    Social Connectedness Index (SCI)
# 6                  Native Land (Indigenous Land Maps)
# 7                 Geomorpho90m Geomorphometric Layers
# 8              Bare Earth’s Surface Spectra 1980-2019
# 9   Normalized Sentinel-1 Global Backscatter Model...
# 10   Soil Organic Carbon Stocks & Trends South Africa
# 11  Soil nematode abundance & functional group com...
# 12                       Global maps of habitat types
# 13  Soil carbon storage in terrestrial ecosystems ...
# 14  Global Surface water and groundwater salinity ...
# 15                               Soil Grids 250m v2.0
# 16                               Soil Properties 800m
# 17  iSDAsoil Predicted Soil Properties for Africa 30m
# 18       Polaris 30m Probabilistic Soil Properties US
# 19                            HiHydroSoil v2.0 layers
# 20                            Global Mangrove Project
# 21  ESRI 2020 Global Land Use Land Cover from Sent...
# 22         ESA WorldCover 10 m 2020 V100 InputQuality
# 23         Global Impervious Surface Area (1972-2019)
# 24             Global urban extents from 1870 to 2100
# 25             World Settlement Footprint & Evolution
# 26           Mapbiomas Annual land cover and use maps
# 27  Land Change Monitoring, Assessment, and Projec...
# 28                    West Africa Land Use Land Cover
# 29             South African National Land Cover 2018
# 30  Mississippi River Basin Floodplain Land Use Ch...
# 31  Continental-scale land cover mapping at 10 m r...
# 32  High-resolution annual forest land cover maps ...
# 33                         Oil Palm Plantation Layers
# 34   Rasterized building footprint dataset for the US
# 35                           Global Shoreline Dataset
# 36    OSM Water Layer Surface Waters in OpenStreetMap
# 37       Global 30m Height Above the Nearest Drainage
# 38                                    HydroLAKES v1.0
# 39             Global River Width from Landsat (GRWL)
# 40  Global coastal rivers and environmental variables
# 41              Global River Deltas and vulnerability
# 42    General Bathymetric Chart of the Oceans (GEBCO)
# 43       Global georeferenced Database of Dams(GOODD)
# 44                            Argo Float Data(Subset)
# 45  National Wetland Inventory (Surface Water and ...
# 46                     Tensor Flow Hydra Flood Models
# 47                         Landfire Mosaics LF v2.0.0
# 48                 Vegetation dryness for western USA
# 49                 Rangeland Analysis Platform layers
# 50                                NASA Harvest Layers
# 51             Benchmark maps Secondary Forest Brazil
# 52             Global irrigation areas (2001 to 2015)
# 53                       Tile Drained Croplands (30m)
# 54           Global crop production tillage practices
# 55                                       Global Power
# 56         Facebook Electrical Distribution Grid Maps
# 57    Harmonized Global Night Time Lights (1992-2020)
# 58                     Global Roads Inventory Project
# 59        Global Mining Areas and Validation Datasets
# 60                 Global Healthsites Mapping Project
# 61  Global fixed broadband and mobile (cellular) n...
# 62                        Global Power Plant Database
# 63               Global offshore wind turbine dataset
# 64  Harmonised global datasets of wind and solar f...
# 65        Global Database of Cement Production Assets
# 66  Global Database of Iron and Steel Production A...
# 67         Global Photovoltaics Inventory (2016-2018)
# 68                         Global Consensus Landcover
# 69                        Global Freshwater Variables
# 70                       Global Habitat Heterogeneity
# 71                            Global 1-km Cloud Cover
# 72         Global Reference Evapotranspiration Layers
# 73                               Global Aridity Index
# 74                         Global Wind Atlas Datasets
# 75                        Global Solar Atlas Datasets
# 76  International Satellite Cloud Climatology Proj...
# 77  Current and projected climate data for North A...
# 78  MODIS Gap filled Long-term Land Surface Temper...
# 79               United States Drought Monitor Layers
# 80  High-spatial-resolution Thermal-stress Indices...
# 81                      Global Fire Atlas (2003-2016)
# 82  Monitoring Trends in Burn Severity (MTBS) 1984...
# 83                                Landsat Burned Area
# 84              Global large flood events (1985-2016)
# 85               Global Landslide Catalog (1970-2019)
# 86    Geocoded Disasters (GDIS) Dataset (1960 – 2018)
#
#                           md_file  \
# 0                projects/hrsl.md
# 1               projects/GPWv4.md
# 2         projects/geoboundary.md
# 3               projects/wacvm.md
# 4                 projects/rwi.md
# 5                 projects/sci.md
# 6              projects/native.md
# 7         projects/geomorpho90.md
# 8                 projects/bss.md
# 9               projects/s1gbm.md
# 10                projects/soc.md
# 11      projects/soil_nematode.md
# 12            projects/habitat.md
# 13                projects/scs.md
# 14           projects/salinity.md
# 15              projects/isric.md
# 16           projects/soilprop.md
# 17               projects/isda.md
# 18            projects/polaris.md
# 19       projects/hihydro_soil.md
# 20           projects/mangrove.md
# 21         projects/esrilc2020.md
# 22             projects/esa_iq.md
# 23               projects/gisa.md
# 24                projects/gue.md
# 25                projects/wsf.md
# 26          projects/mapbiomas.md
# 27              projects/lcmap.md
# 28            projects/wa_lulc.md
# 29         projects/sa_nlc2018.md
# 30      projects/floodplain_lc.md
# 31                projects/elc.md
# 32              projects/ca_lc.md
# 33           projects/oil-palm.md
# 34     projects/usbuild_raster.md
# 35          projects/shoreline.md
# 36          projects/osm_water.md
# 37               projects/hand.md
# 38         projects/hydrolakes.md
# 39               projects/grwl.md
# 40         projects/rivermouth.md
# 41       projects/river_deltas.md
# 42              projects/gebco.md
# 43              projects/goodd.md
# 44               projects/argo.md
# 45                projects/nwi.md
# 46        projects/hydra_water.md
# 47           projects/landfire.md
# 48            projects/veg_dry.md
# 49                projects/rap.md
# 50            projects/harvest.md
# 51   projects/secondary_forest.md
# 52  projects/global_irrigation.md
# 53               projects/tile.md
# 54            projects/tillage.md
# 55       projects/global_power.md
# 56      projects/electric_grid.md
# 57               projects/hntl.md
# 58               projects/grip.md
# 59      projects/global_mining.md
# 60       projects/health_sites.md
# 61          projects/speedtest.md
# 62           projects/pwplants.md
# 63               projects/gowt.md
# 64       projects/energy_farms.md
# 65                projects/gcd.md
# 66                projects/gid.md
# 67          projects/global_pv.md
# 68                projects/gcl.md
# 69                projects/gfv.md
# 70                projects/ghh.md
# 71                projects/gcc.md
# 72                projects/et0.md
# 73                projects/ai0.md
# 74                projects/gwa.md
# 75                projects/gsa.md
# 76          projects/isccp_hxg.md
# 77        projects/aogcm_cmip6.md
# 78          projects/daily_lst.md
# 79               projects/usdm.md
# 80            projects/hitisae.md
# 81                projects/gfa.md
# 82               projects/mtbs.md
# 83                projects/lba.md
# 84              projects/flood.md
# 85          projects/landslide.md
# 86               projects/gdis.md
#
#                                       years_mentioned  \
# 0                                  [2016, 2016, 2021]
# 1   [2000, 2005, 2010, 2015, 2020, 2010, 2010, 201...
# 2                            [2017, 2020, 2017, 2021]
# 3    [2010, 2000, 2005, 2008, 2000, 1997, 2018, 2021]
# 4                                              [2021]
# 5                                        [2018, 2021]
# 6                                  [2021, 2021, 2021]
# 7                                        [2020, 2021]
# 8                      [1980, 2020, 1980, 1980, 2021]
# 9                      [2016, 2016, 2021, 2021, 2021]
# 10  [1984, 2021, 1984, 2019, 1984, 2019, 2020, 198...
# 11                                 [2020, 2020, 2021]
# 12  [2015, 2020, 2015, 2016, 2017, 2017, 2016, 201...
# 13   [2020, 2018, 2019, 2015, 2020, 2021, 2021, 2021]
# 14         [1980, 1980, 2020, 1980, 1980, 2020, 2021]
# 15                                 [2020, 2016, 2020]
# 16                                       [2020, 2021]
# 17                                       [2021, 2021]
# 18         [2018, 2019, 2019, 2019, 2019, 2019, 2021]
# 19               [2020, 2020, 2020, 2009, 2020, 2021]
# 20  [1996, 2016, 2010, 1996, 2016, 2018, 2018, 201...
# 21  [2020, 2020, 2020, 2021, 2021, 2021, 2020, 202...
# 22                     [2020, 2020, 2021, 2020, 2021]
# 23  [1972, 1972, 2019, 1985, 1972, 1972, 1978, 198...
# 24  [1992, 2013, 1990, 2020, 1990, 1992, 2013, 202...
# 25  [2015, 2015, 2015, 2015, 2015, 2015, 2019, 201...
# 26                                 [2016, 2017, 2019]
# 27  [1985, 1976, 2020, 1984, 2020, 2014, 2020, 198...
# 28  [1999, 1975, 2000, 2013, 2016, 1975, 1975, 200...
# 29  [2018, 2018, 2018, 2018, 2018, 1990, 2013, 201...
# 30  [1941, 1941, 2021, 1950, 1941, 1960, 1941, 197...
# 31         [2018, 2019, 2021, 2019, 2020, 2018, 2021]
# 32  [1984, 1984, 2019, 2022, 2018, 2022, 2021, 201...
# 33  [1984, 2017, 1984, 1985, 2017, 2021, 1984, 202...
# 34                           [2018, 2020, 2020, 2021]
# 35                           [2014, 2019, 2018, 2020]
# 36                                       [2019, 2020]
# 37                           [2016, 2016, 2016, 2017]
# 38  [2013, 2006, 2009, 2013, 2012, 2004, 2011, 201...
# 39                           [2018, 2018, 2018, 2021]
# 40                                 [2019, 2019, 2021]
# 41                                 [2020, 2020, 2021]
# 42  [2021, 2030, 2021, 2021, 2019, 2030, 2021, 202...
# 43                                 [2020, 2020, 2021]
# 44               [2000, 2020, 2020, 2020, 2020, 2021]
# 45                           [2009, 2018, 2021, 2021]
# 46                                       [2021, 2021]
# 47                           [2016, 2013, 2013, 2021]
# 48  [2016, 2020, 2020, 2021, 2019, 2019, 2019, 202...
# 49  [1984, 1986, 2020, 2020, 2020, 2019, 2020, 202...
# 50   [2006, 2020, 2020, 2019, 2020, 2020, 2019, 2021]
# 51  [1986, 2030, 1985, 2018, 1986, 2020, 2020, 201...
# 52  [2001, 2015, 2000, 2001, 2015, 2001, 2001, 201...
# 53                                 [1990, 2020, 2021]
# 54                     [1980, 2017, 2020, 2021, 2021]
# 55                           [2020, 2020, 2020, 2021]
# 56                                             [2021]
# 57  [1992, 1992, 1992, 2014, 1992, 2020, 1992, 199...
# 58                                       [2018, 2021]
# 59         [2000, 2017, 2017, 2018, 2020, 2020, 2021]
# 60                                             [2021]
# 61  [2019, 2021, 2020, 2020, 2020, 2020, 2021, 202...
# 62  [2021, 2020, 2019, 2013, 2013, 2013, 2014, 201...
# 63                     [2015, 2019, 2021, 2020, 2021]
# 64                     [2020, 2020, 2020, 2020, 2021]
# 65                                       [2021, 2021]
# 66                                       [2021, 2021]
# 67  [2016, 2009, 2040, 2018, 2021, 2021, 2017, 201...
# 68                                 [2014, 2014, 2021]
# 69                     [2015, 2015, 2015, 2015, 2021]
# 70                                 [2015, 2015, 2021]
# 71                                       [2016, 2016]
# 72         [1970, 1998, 2000, 1998, 2019, 1970, 2021]
# 73                           [1970, 2019, 2070, 2021]
# 74                                             [2021]
# 75                           [2021, 2016, 1994, 2021]
# 76                                 [2021, 1982, 1999]
# 77                     [2021, 2021, 2016, 2087, 2021]
# 78  [2003, 2020, 2003, 2018, 2020, 2020, 2021, 200...
# 79                                 [1999, 2000, 2021]
# 80         [1981, 2019, 2021, 2021, 1981, 2021, 2021]
# 81  [2003, 2019, 2019, 2003, 2003, 2004, 2004, 200...
# 82  [1984, 1984, 2007, 2017, 2017, 2017, 2017, 200...
# 83  [1984, 2020, 2020, 2017, 1984, 2015, 2017, 201...
# 84               [1985, 1985, 2016, 2017, 1985, 2021]
# 85         [1970, 2007, 2010, 2015, 2015, 1970, 2021]
# 86  [1960, 2018, 1960, 2018, 2018, 1960, 2021, 202...
#
#     temporal_resolution_yrs  \
# 0                       5.0
# 1                       5.0
# 2                       4.0
# 3                      21.0
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                      41.0
# 9                       5.0
# 10                    -36.0
# 11                      1.0
# 12                      0.0
# 13                      5.0
# 14                     40.0
# 15                      4.0
# 16                      NaN
# 17                      NaN
# 18                      0.0
# 19                      1.0
# 20                     11.0
# 21                      1.0
# 22                     -1.0
# 23                     47.0
# 24                     -1.0
# 25                      0.0
# 26                      2.0
# 27                    -35.0
# 28                     13.0
# 29                      0.0
# 30                      0.0
# 31                     -2.0
# 32                     38.0
# 33                      2.0
# 34                      1.0
# 35                      2.0
# 36                      NaN
# 37                      NaN
# 38                      5.0
# 39                      NaN
# 40                      2.0
# 41                      1.0
# 42                      0.0
# 43                      1.0
# 44                      0.0
# 45                      0.0
# 46                      NaN
# 47                      8.0
# 48                     -2.0
# 49                      1.0
# 50                     -1.0
# 51                    -26.0
# 52                      0.0
# 53                      1.0
# 54                      0.0
# 55                      NaN
# 56                      NaN
# 57                    -28.0
# 58                      NaN
# 59                      1.0
# 60                      NaN
# 61                      0.0
# 62                      0.0
# 63                      1.0
# 64                      0.0
# 65                      NaN
# 66                      NaN
# 67                      1.0
# 68                      7.0
# 69                      0.0
# 70                      6.0
# 71                      NaN
# 72                     51.0
# 73                    -49.0
# 74                      NaN
# 75                     27.0
# 76                     17.0
# 77                    -66.0
# 78                      1.0
# 79                     21.0
# 80                     40.0
# 81                      1.0
# 82                     37.0
# 83                     -2.0
# 84                     36.0
# 85                     51.0
# 86                     61.0
#
#                                  spatial_resolution_m                datatype  \
# 0                                                  []  ImageCollection||Image
# 1                                                  []       FeatureCollection
# 2                                                  []       FeatureCollection
# 3                                                  []       FeatureCollection
# 4                                    [4000.0, 4000.0]  ImageCollection||Image
# 5                                                  []       FeatureCollection
# 6                                                  []       FeatureCollection
# 7                            [90.0, 90.0, 90.0, 90.0]  ImageCollection||Image
# 8                                                  []  ImageCollection||Image
# 9        [100000.0, 100000.0, 10.0, 10.0, 10.0, 10.0]       FeatureCollection
# 10                                       [30.0, 30.0]  ImageCollection||Image
# 11                                                 []       FeatureCollection
# 12                                                 []  ImageCollection||Image
# 13                                [250.0, 1.0, 250.0]  ImageCollection||Image
# 14                                                 []       FeatureCollection
# 15                                            [250.0]  ImageCollection||Image
# 16                                                 []  ImageCollection||Image
# 17                                       [30.0, 30.0]  ImageCollection||Image
# 18                                             [30.0]  ImageCollection||Image
# 19                                            [250.0]  ImageCollection||Image
# 20                                                 []       FeatureCollection
# 21                                             [10.0]  ImageCollection||Image
# 22                                 [10.0, 10.0, 10.0]  ImageCollection||Image
# 23                                       [30.0, 30.0]  ImageCollection||Image
# 24                                                 []  ImageCollection||Image
# 25             [222000.0, 222000.0, 10.0, 10.0, 30.0]  ImageCollection||Image
# 26                                                 []  ImageCollection||Image
# 27                                                 []  ImageCollection||Image
# 28                                                 []  ImageCollection||Image
# 29                                                 []  ImageCollection||Image
# 30                                                 []  ImageCollection||Image
# 31                           [10.0, 10.0, 10.0, 10.0]  ImageCollection||Image
# 32                                         [150000.0]  ImageCollection||Image
# 33                                         [100000.0]  ImageCollection||Image
# 34                                             [30.0]  ImageCollection||Image
# 35                                                 []       FeatureCollection
# 36                                                 []  ImageCollection||Image
# 37                                       [30.0, 30.0]  ImageCollection||Image
# 38                 [1000.0, 1000.0, 30.0, 90.0, 90.0]       FeatureCollection
# 39                                                 []       FeatureCollection
# 40                                                 []       FeatureCollection
# 41                                                 []       FeatureCollection
# 42                                                 []  ImageCollection||Image
# 43                                                 []       FeatureCollection
# 44                                                 []       FeatureCollection
# 45                                                 []       FeatureCollection
# 46                                                 []  ImageCollection||Image
# 47                                                 []  ImageCollection||Image
# 48                                            [250.0]  ImageCollection||Image
# 49                                             [30.0]  ImageCollection||Image
# 50                                                 []  ImageCollection||Image
# 51                                                 []  ImageCollection||Image
# 52                                           [9000.0]  ImageCollection||Image
# 53                                             [30.0]  ImageCollection||Image
# 54                                                 []       FeatureCollection
# 55                                                 []  ImageCollection||Image
# 56                                                 []  ImageCollection||Image
# 57                                                 []  ImageCollection||Image
# 58                                                 []       FeatureCollection
# 59                                                 []       FeatureCollection
# 60                                                 []       FeatureCollection
# 61                                            [610.0]  ImageCollection||Image
# 62                                                 []       FeatureCollection
# 63                                             [10.0]       FeatureCollection
# 64                                                 []       FeatureCollection
# 65                                                 []       FeatureCollection
# 66                                                 []       FeatureCollection
# 67                                                 []       FeatureCollection
# 68                                                 []  ImageCollection||Image
# 69                   [1000.0, 1000.0, 1000.0, 1000.0]  ImageCollection||Image
# 70  [5000.0, 25000.0, 1000.0, 1000.0, 5000.0, 2500...  ImageCollection||Image
# 71                                                 []  ImageCollection||Image
# 72                                           [1000.0]  ImageCollection||Image
# 73                                           [1000.0]  ImageCollection||Image
# 74              [10000.0, 250.0, 150.0, 250.0, 100.0]  ImageCollection||Image
# 75                                              [2.0]  ImageCollection||Image
# 76                                                 []  ImageCollection||Image
# 77                                           [1000.0]  ImageCollection||Image
# 78                   [1000.0, 1000.0, 1000.0, 1000.0]  ImageCollection||Image
# 79                                                 []  ImageCollection||Image
# 80                                                 []  ImageCollection||Image
# 81                                                 []       FeatureCollection
# 82                                                 []       FeatureCollection
# 83                                                 []  ImageCollection||Image
# 84                                                 []       FeatureCollection
# 85                                                 []       FeatureCollection
# 86                                                 []       FeatureCollection
#
#    updated_year processing_level
# 0          2021             TODO
# 1          2021             TODO
# 2          2021             TODO
# 3          2021             TODO
# 4           NaT             TODO
# 5          2021             TODO
# 6          2021             TODO
# 7          2021             TODO
# 8          2021             TODO
# 9          2021             TODO
# 10         2021             TODO
# 11         2021             TODO
# 12         2020             TODO
# 13         2021             TODO
# 14         2021             TODO
# 15         2020             TODO
# 16         2021             TODO
# 17         2021             TODO
# 18         2019             TODO
# 19         2020             TODO
# 20         2019             TODO
# 21         2021             TODO
# 22         2021             TODO
# 23         2021             TODO
# 24         2021             TODO
# 25         2021             TODO
# 26          NaT             TODO
# 27         2021             TODO
# 28         2021             TODO
# 29         2021             TODO
# 30         2021             TODO
# 31         2021             TODO
# 32         2021             TODO
# 33         2021             TODO
# 34         2021             TODO
# 35         2020             TODO
# 36         2020             TODO
# 37         2017             TODO
# 38         2021             TODO
# 39         2021             TODO
# 40         2021             TODO
# 41         2021             TODO
# 42         2021             TODO
# 43         2021             TODO
# 44         2021             TODO
# 45         2021             TODO
# 46         2021             TODO
# 47         2013             TODO
# 48         2021             TODO
# 49         2021             TODO
# 50          NaT             TODO
# 51         2020             TODO
# 52         2001             TODO
# 53         2021             TODO
# 54         2021             TODO
# 55         2021             TODO
# 56         2021             TODO
# 57         2021             TODO
# 58         2021             TODO
# 59         2021             TODO
# 60          NaT             TODO
# 61         2020             TODO
# 62          NaT             TODO
# 63         2021             TODO
# 64         2021             TODO
# 65         2021             TODO
# 66         2021             TODO
# 67         2021             TODO
# 68         2021             TODO
# 69         2021             TODO
# 70         2021             TODO
# 71          NaT             TODO
# 72         2021             TODO
# 73         2021             TODO
# 74         2021             TODO
# 75         2021             TODO
# 76          NaT             TODO
# 77         2021             TODO
# 78         2021             TODO
# 79          NaT             TODO
# 80         2021             TODO
# 81         2019             TODO
# 82         2021             TODO
# 83         2021             TODO
# 84         2021             TODO
# 85         2021             TODO
# 86         2021             TODO
